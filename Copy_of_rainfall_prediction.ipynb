# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# Read the CSV file into a DataFrame
df = pd.read_csv('indiarainfall.csv')

# Plot the rainfall data
df.plot(x='YEAR', y=['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'], figsize=(14, 8))

# Customize the plot
plt.title('Monthly Rainfall in India')
plt.ylabel('Rainfall (mm)')
plt.xlabel('Year')
plt.legend(title='Month')
plt.show()

# %%
annual_rainfall = df['ANNUAL']
print(annual_rainfall)
cols=list(df)[14:15]
# Out:
# 0       3373.2
# 1       3520.7
# 2       2957.4
# 3       3079.6
# 4       2566.7
#          ...
# 4183    1426.3
# 4184    1395.0
# 4185    1642.9
# 4186    1065.7
# 4187    1738.9
# Name: ANNUAL, Length: 4188, dtype: float64

# %%
training_df=df[cols].astype(float)
plot_df=training_df
plot_df.plot.line()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the annual rainfall data
scaler.fit(df[['ANNUAL']])

# Transform the annual rainfall data using the fitted scaler
annual_rainfall_scaled = scaler.transform(df[['ANNUAL']])

# Print the scaled data
print(annual_rainfall_scaled)
# Out:
# [[ 2.16429405]
#  [ 2.3271326 ]
#  [ 1.70525492]
#  ...
#  [ 0.2540598 ]
#  [-0.38316334]
#  [ 0.36004286]]

# %%
'''from sklearn.model_selection import train_test_split

# Split the data into training and test sets
trainX, testX, trainY, testY = train_test_split(trainX, trainY, test_size=0.2)

# Print the shapes of the training and test sets
print('Shape of training data (X):', trainX.shape)
print(trainX)
print('Shape of training data (Y):', trainY.shape)
print('Shape of test data (X):', testX.shape)
print('Shape of test data (Y):', testY.shape)

'''
from sklearn.model_selection import train_test_split

# Lists for storing the training and testing data
trainX = []
trainY = []

n_past = 20  # 20 values will be considered to predict the next value

# Adding the values to trainX and trainY lists
for i in range(n_past, len(annual_rainfall_scaled)):
    trainX.append(annual_rainfall_scaled[i - n_past:i])
    trainY.append(annual_rainfall_scaled[i])

# Converting into numpy arrays
trainX, trainY = np.array(trainX), np.array(trainY)

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(trainX, trainY, test_size=0.2, shuffle=False)

print('X_train shape == {}'.format(X_train.shape))
print('y_train shape == {}'.format(y_train.shape))
print('X_test shape == {}'.format(X_test.shape))
print('y_test shape == {}'.format(y_test.shape))
# Out:
# X_train shape == (3334, 20, 1)
# y_train shape == (3334, 1)
# X_test shape == (834, 20, 1)
# y_test shape == (834, 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# Define the model
model = Sequential()

# Add the first LSTM layer
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

# Add the second LSTM layer
model.add(LSTM(32, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Add the third LSTM layer
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))

from keras.regularizers import l2

# Add L2 regularization to Dense layers
model.add(Dense(trainY.shape[1], kernel_regularizer=l2(0.01)))

# Add the output layer
model.add(Dense(trainY.shape[1]))

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20, 64)            16896
#
#  dropout (Dropout)           (None, 20, 64)            0
#
#  lstm_1 (LSTM)               (None, 20, 32)            12416
#
#  dropout_1 (Dropout)         (None, 20, 32)            0
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 37667 (147.14 KB)
# Trainable params: 37667 (147.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(trainX, trainY, epochs=100, batch_size=20, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 10s 32ms/step - loss: 0.3139 - val_loss: 0.2510
# Epoch 2/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.2033 - val_loss: 0.2208
# Epoch 3/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1896 - val_loss: 0.2156
# Epoch 4/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1796 - val_loss: 0.2047
# Epoch 5/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1718 - val_loss: 0.2268
# Epoch 6/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1728 - val_loss: 0.1826
# Epoch 7/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1631 - val_loss: 0.1851
# Epoch 8/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1560 - val_loss: 0.1943
# Epoch 9/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1650 - val_loss: 0.1817
# Epoch 10/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1592 - val_loss: 0.2151
# Epoch 11/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1566 - val_loss: 0.1731
# Epoch 12/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1536 - val_loss: 0.1754
# Epoch 13/100
# 188/188 [==============================] - 5s 29ms/step - loss: 0.1614 - val_loss: 0.1738
# Epoch 14/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1458 - val_loss: 0.1654
# Epoch 15/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1526 - val_loss: 0.1668
# Epoch 16/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1516 - val_loss: 0.1598
# Epoch 17/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1501 - val_loss: 0.1849
# Epoch 18/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1541 - val_loss: 0.1614
# Epoch 19/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1407 - val_loss: 0.1691
# Epoch 20/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1466 - val_loss: 0.1744
# Epoch 21/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1536 - val_loss: 0.1641
# Epoch 22/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1473 - val_loss: 0.1573
# Epoch 23/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1462 - val_loss: 0.1699
# Epoch 24/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1413 - val_loss: 0.1562
# Epoch 25/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1434 - val_loss: 0.1609
# Epoch 26/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1437 - val_loss: 0.1580
# Epoch 27/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1412 - val_loss: 0.1676
# Epoch 28/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1405 - val_loss: 0.1726
# Epoch 29/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1395 - val_loss: 0.1553
# Epoch 30/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1469 - val_loss: 0.1745
# Epoch 31/100
# 188/188 [==============================] - 6s 29ms/step - loss: 0.1439 - val_loss: 0.1602
# Epoch 32/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1385 - val_loss: 0.1699
# Epoch 33/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1366 - val_loss: 0.1504
# Epoch 34/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1398 - val_loss: 0.1653
# Epoch 35/100
# 188/188 [==============================] - 5s 29ms/step - loss: 0.1348 - val_loss: 0.1524
# Epoch 36/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1393 - val_loss: 0.1505
# Epoch 37/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1396 - val_loss: 0.1524
# Epoch 38/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1326 - val_loss: 0.1679
# Epoch 39/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1385 - val_loss: 0.1557
# Epoch 40/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1384 - val_loss: 0.1517
# Epoch 41/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1380 - val_loss: 0.1566
# Epoch 42/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1374 - val_loss: 0.1489
# Epoch 43/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1392 - val_loss: 0.1593
# Epoch 44/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1349 - val_loss: 0.1548
# Epoch 45/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1354 - val_loss: 0.1589
# Epoch 46/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1314 - val_loss: 0.1447
# Epoch 47/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1359 - val_loss: 0.1478
# Epoch 48/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1319 - val_loss: 0.1486
# Epoch 49/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1404 - val_loss: 0.1547
# Epoch 50/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1368 - val_loss: 0.1518
# Epoch 51/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1339 - val_loss: 0.1501
# Epoch 52/100
# 188/188 [==============================] - 5s 29ms/step - loss: 0.1293 - val_loss: 0.1569
# Epoch 53/100
# 188/188 [==============================] - 5s 28ms/step - loss: 0.1332 - val_loss: 0.1495
# Epoch 54/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1343 - val_loss: 0.1476
# Epoch 55/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1328 - val_loss: 0.1499
# Epoch 56/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1341 - val_loss: 0.1533
# Epoch 57/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1334 - val_loss: 0.1474
# Epoch 58/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1337 - val_loss: 0.1504
# Epoch 59/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1304 - val_loss: 0.1481
# Epoch 60/100
# 188/188 [==============================] - 6s 32ms/step - loss: 0.1306 - val_loss: 0.1460
# Epoch 61/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1297 - val_loss: 0.1527
# Epoch 62/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1298 - val_loss: 0.1489
# Epoch 63/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1317 - val_loss: 0.1495
# Epoch 64/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1283 - val_loss: 0.1462
# Epoch 65/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1294 - val_loss: 0.1770
# Epoch 66/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1289 - val_loss: 0.1452
# Epoch 67/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1344 - val_loss: 0.1458
# Epoch 68/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1316 - val_loss: 0.1551
# Epoch 69/100
# 188/188 [==============================] - 5s 29ms/step - loss: 0.1266 - val_loss: 0.1459
# Epoch 70/100
# 188/188 [==============================] - 5s 28ms/step - loss: 0.1331 - val_loss: 0.1457
# Epoch 71/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1321 - val_loss: 0.1450
# Epoch 72/100
# 188/188 [==============================] - 6s 32ms/step - loss: 0.1294 - val_loss: 0.1489
# Epoch 73/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1314 - val_loss: 0.1539
# Epoch 74/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1224 - val_loss: 0.1513
# Epoch 75/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1288 - val_loss: 0.1465
# Epoch 76/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1277 - val_loss: 0.1516
# Epoch 77/100
# 188/188 [==============================] - 6s 33ms/step - loss: 0.1304 - val_loss: 0.1516
# Epoch 78/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1268 - val_loss: 0.1561
# Epoch 79/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1302 - val_loss: 0.1551
# Epoch 80/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1259 - val_loss: 0.1504
# Epoch 81/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1248 - val_loss: 0.1515
# Epoch 82/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1291 - val_loss: 0.1537
# Epoch 83/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1274 - val_loss: 0.1654
# Epoch 84/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1303 - val_loss: 0.1492
# Epoch 85/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1275 - val_loss: 0.1718
# Epoch 86/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1255 - val_loss: 0.1698
# Epoch 87/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1298 - val_loss: 0.1541
# Epoch 88/100
# 188/188 [==============================] - 5s 25ms/step - loss: 0.1275 - val_loss: 0.1517
# Epoch 89/100
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1227 - val_loss: 0.1535
# Epoch 90/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1228 - val_loss: 0.1626
# Epoch 91/100
# 188/188 [==============================] - 6s 32ms/step - loss: 0.1281 - val_loss: 0.1526
# Epoch 92/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1252 - val_loss: 0.1576
# Epoch 93/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1296 - val_loss: 0.1550
# Epoch 94/100
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1237 - val_loss: 0.1505
# Epoch 95/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1287 - val_loss: 0.1583
# Epoch 96/100
# 188/188 [==============================] - 6s 32ms/step - loss: 0.1282 - val_loss: 0.1529
# Epoch 97/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1210 - val_loss: 0.1557
# Epoch 98/100
# 188/188 [==============================] - 6s 32ms/step - loss: 0.1264 - val_loss: 0.1549
# Epoch 99/100
# 188/188 [==============================] - 5s 26ms/step - loss: 0.1247 - val_loss: 0.1580
# Epoch 100/100
# 188/188 [==============================] - 5s 27ms/step - loss: 0.1276 - val_loss: 0.1585

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test data


mse = model.evaluate(X_test, y_test)

# Print the MSE
print("Test MSE:", mse)
# Evaluate the model on training and testing data
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

# Print the MSE values
print("Training MSE:", train_loss)
print("Testing MSE:", test_loss)
#This code will print the Mean Squared Error (MSE)

from sklearn.metrics import r2_score

# Predict on training and validation sets
train_pred = model.predict(X_train)
val_pred = model.predict(X_test)

# Calculate R-squared (R^2) score for training and validation sets
train_r2 = r2_score(y_train, train_pred)
val_r2 = r2_score(y_test, val_pred)

# Print the R-squared (R^2) scores
print("Training R-squared (R^2) score:", train_r2)
print("Validation R-squared (R^2) score:", val_r2)


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predict on training and validation sets
train_pred = model.predict(X_train)
val_pred = model.predict(X_test)

# Calculate evaluation metrics for training set
train_mae = mean_absolute_error(y_train, train_pred)
train_rmse = mean_squared_error(y_train, train_pred, squared=False)
train_r2 = r2_score(y_train, train_pred)

# Calculate evaluation metrics for validation set
val_mae = mean_absolute_error(y_test, val_pred)
val_rmse = mean_squared_error(y_test, val_pred, squared=False)
val_r2 = r2_score(y_test, val_pred)

# Create a DataFrame to store the evaluation metrics
metrics_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE', 'R-squared'],
    'Training': [train_mae, train_rmse, train_r2],
    'Validation': [val_mae, val_rmse, val_r2]
})

# Print the accuracy table
print(metrics_df)
# Out:
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1618
# Test MSE: 0.1617586314678192
# Training MSE: 0.11126207560300827
# Testing MSE: 0.1617586314678192
# 105/105 [==============================] - 1s 12ms/step
# 27/27 [==============================] - 0s 9ms/step
# Training R-squared (R^2) score: 0.876983468691582
# Validation R-squared (R^2) score: 0.8813251012207699
# 105/105 [==============================] - 1s 8ms/step
# 27/27 [==============================] - 0s 9ms/step
#       Metric  Training  Validation
# 0        MAE  0.233104    0.269586
# 1       RMSE  0.330328    0.399516
# 2  R-squared  0.876983    0.881325

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
from sklearn.preprocessing import StandardScaler
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())

n_past = 100
n_days_for_prediction=100

#predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq=us_bd).tolist()
#years = [date.year for date in predict_period_dates]
start_year = 2024
end_year = 2034  # Predicting for the next 10 years

# Generate a list of dates for the extended prediction period
extended_predict_period_dates = pd.date_range(start=f"{start_year}-01-01", end=f"{end_year}-12-31", freq=us_bd).tolist()

#print(years)

# make prediction
#prediction = model.predict(trainX[-n_days_for_prediction:]) #shape = (n, 1) where n is the n_days_for_prediction
# Make predictions for the extended prediction period
#print(extended_predict_period_dates)
extended_prediction = model.predict(trainX[-len(extended_predict_period_dates):])
#print(len(extended_prediction))
#print(prediction)
#Perform inverse transformation to rescale back to original range
#Since we used 1 variables for transform, the inverse expects same dimensions

extended_prediction_copies = np.repeat(extended_prediction, training_df.shape[1], axis=-1)
y_pred_extended = scaler.inverse_transform(extended_prediction_copies)[:, 0]
#print(y_pred_extended)
df_extended_forecast = pd.DataFrame({'YEAR': [date.year for date in extended_predict_period_dates],
                                    # "Month" : [date.month for date in extended_predict_period_dates],
                                     'ANNUAL': y_pred_extended})

df_list = df_extended_forecast.values.tolist()
predictions = []
year = []

for i in range (start_year, end_year+1):
  count = 0
  data= []
  for j in range(len(df_list)):
    if int(df_list[j][0]) == i:
      data.append(df_list[j][1])
      count +=1
  actual_rain = sum(data)/len(data)
  #print(count)
  predictions.append(actual_rain)
  year.append(i)
#print(df_list)
#print(predictions)
#print(year)
# Out:
# 86/86 [==============================] - 1s 9ms/step

# %%
import matplotlib.pyplot as plt


# Plotting the line graph
plt.plot(year, predictions, marker='o', color='blue', label='Prediction')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Prediction')
plt.title('Prediction over Years')

# Show plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-80878219860a> in <cell line: 5>()
#       3
#       4 # Plotting the line graph
# ----> 5 plt.plot(year, predictions, marker='o', color='blue', label='Prediction')
#       6
#       7 # Adding labels and title
#
# NameError: name 'year' is not defined
